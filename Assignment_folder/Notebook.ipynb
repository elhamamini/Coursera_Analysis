# %%
import pandas as pd
import json
from pandas import json_normalize
from sklearn.preprocessing import LabelEncoder
from ua_parser import user_agent_parser
from user_agents import parse

# %%
df = pd.read_csv('psy-001_clickstream_export_snippet.txt', sep="|",header=None)
df
# Out:
#                                   0   \
# 0                     {key: pageview
# 1                     {key: pageview
# 2    {key: user.video.lecture.action
# 3    {key: user.video.lecture.action
# 4    {key: user.video.lecture.action
# ..                               ...
# 233                   {key: pageview
# 234  {key: user.video.lecture.action
# 235  {key: user.video.lecture.action
# 236  {key: user.video.lecture.action
# 237                   {key: pageview
#
#                                                     1   \
# 0                                            value: {}
# 1                                            value: {}
# 2    value: {\currentTime\:152.39935302734375,\play...
# 3    value: {\currentTime\:167.00390625,\playbackRa...
# 4    value: {\currentTime\:196.21298217773438,\play...
# ..                                                 ...
# 233                                          value: {}
# 234  value: {\currentTime\:0,\playbackRate\:1,\paus...
# 235  value: {\currentTime\:283.8022155761719,\playb...
# 236  value: {\currentTime\:0,\playbackRate\:1,\paus...
# 237                                          value: {}
#
#                                                     2   \
# 0    username: 728a8ca729e62014cf146709f8dfceddb3af...
# 1    username: 728a8ca729e62014cf146709f8dfceddb3af...
# 2    username: 1d9e48276af48ba4d2e4ceb7532001433024...
# 3    username: 1d9e48276af48ba4d2e4ceb7532001433024...
# 4    username: 1d9e48276af48ba4d2e4ceb7532001433024...
# ..                                                 ...
# 233  username: 246f9877ed2a111a19565237116faafbcf8b...
# 234  username: c16a6fe0421893b83ff0924ff356d0db1027...
# 235  username: 9f195402d917fc3f616a035ce69e142332f8...
# 236  username: c16a6fe0421893b83ff0924ff356d0db1027...
# 237  username: a246e228965378af68fb880ff0c7d27770e4...
#
#                            3   \
# 0    timestamp: 1368217515281
# 1    timestamp: 1368217515334
# 2    timestamp: 1368217516077
# 3    timestamp: 1368217516923
# 4    timestamp: 1368217518608
# ..                        ...
# 233  timestamp: 1368217905782
# 234  timestamp: 1368217908279
# 235  timestamp: 1368217913339
# 236  timestamp: 1368217913569
# 237  timestamp: 1368217913671
#
#                                                     4              5   \
# 0    page_url: https://class.coursera.org/psy-001/h...  client: spark
# 1    page_url: https://class.coursera.org/psy-001/w...  client: spark
# 2    page_url: https://class.coursera.org/psy-001/l...  client: spark
# 3    page_url: https://class.coursera.org/psy-001/l...  client: spark
# 4    page_url: https://class.coursera.org/psy-001/l...  client: spark
# ..                                                 ...            ...
# 233  page_url: https://class.coursera.org/psy-001/w...  client: spark
# 234  page_url: https://class.coursera.org/psy-001/l...  client: spark
# 235  page_url: https://class.coursera.org/psy-001/l...  client: spark
# 236  page_url: https://class.coursera.org/psy-001/l...  client: spark
# 237  page_url: https://class.coursera.org/psy-001/q...  client: spark
#
#                                     6   \
# 0    session: 1318904033-1368216996291
# 1    session: 1318904033-1368216996291
# 2    session: 8579605985-1368217057801
# 3    session: 8579605985-1368217057801
# 4    session: 8579605985-1368217057801
# ..                                 ...
# 233  session: 4999032752-1368213768654
# 234  session: 1825227370-1368217101956
# 235  session: 6045169376-1368215391831
# 236  session: 1825227370-1368217101956
# 237  session: 3719122221-1368210759589
#
#                                                 7   \
# 0                         language: es-ES,es;q=0.8
# 1                         language: es-ES,es;q=0.8
# 2                language: es,en-US;q=0.8,en;q=0.6
# 3                language: es,en-US;q=0.8,en;q=0.6
# 4                language: es,en-US;q=0.8,en;q=0.6
# ..                                             ...
# 233                                language: es-es
# 234                       language: en-US,en;q=0.8
# 235  language: ru-RU,ru;q=0.8,en-US;q=0.6,en;q=0.4
# 236                       language: en-US,en;q=0.8
# 237                                language: es-es
#
#                                                     8   \
# 0    from: https://class.coursera.org/psy-001/wiki/...
# 1    from: https://class.coursera.org/psy-001/human...
# 2    from: https://class.coursera.org/psy-001/lectu...
# 3    from: https://class.coursera.org/psy-001/lectu...
# 4    from: https://class.coursera.org/psy-001/lectu...
# ..                                                 ...
# 233  from: https://class.coursera.org/psy-001/lectu...
# 234  from: https://class.coursera.org/psy-001/lectu...
# 235  from: https://class.coursera.org/psy-001/lectu...
# 236  from: https://class.coursera.org/psy-001/lectu...
# 237  from: https://class.coursera.org/psy-001/quiz/...
#
#                            9   \
# 0        user_ip: 66.98.43.34
# 1        user_ip: 66.98.43.34
# 2      user_ip: 81.37.199.142
# 3      user_ip: 81.37.199.142
# 4      user_ip: 81.37.199.142
# ..                        ...
# 233      user_ip: 88.7.114.56
# 234   user_ip: 98.253.201.233
# 235     user_ip: 93.74.47.244
# 236   user_ip: 98.253.201.233
# 237  user_ip: 201.143.189.105
#
#                                                     10
# 0    user_agent: Mozilla/5.0 (Windows NT 6.0) Apple...
# 1    user_agent: Mozilla/5.0 (Windows NT 6.0) Apple...
# 2    user_agent: Mozilla/5.0 (Windows NT 6.1; WOW64...
# 3    user_agent: Mozilla/5.0 (Windows NT 6.1; WOW64...
# 4    user_agent: Mozilla/5.0 (Windows NT 6.1; WOW64...
# ..                                                 ...
# 233  user_agent: Mozilla/5.0 (iPad; CPU OS 6_1_3 li...
# 234  user_agent: Mozilla/5.0 (Linux; Android 4.0.4;...
# 235  user_agent: Mozilla/5.0 (Windows NT 5.1) Apple...
# 236  user_agent: Mozilla/5.0 (Linux; Android 4.0.4;...
# 237  user_agent: Mozilla/5.0 (iPad; CPU OS 6_1 like...
#
# [238 rows x 11 columns]

# %%
result = df.to_json(orient="split")

# %%
parsed = json.loads(result)

List_of_lists=parsed["data"]

# %%
list_of_dict=[]
for line in List_of_lists:
    obj={}
    for row in line:
         command, description = row.strip().split(":",1)
         
         if command=="{key":
                command="key"
      
         obj[command]=description 
        
   
    list_of_dict.append(obj)

# %%
json.dumps(list_of_dict, indent=4)

# %%
with open("my_data.json", "w") as final:
    json.dump(list_of_dict, final)

# %%
Coursera_df = pd.read_json("my_data.json")
Coursera_df
# Out:
#                             key  \
# 0                      pageview
# 1                      pageview
# 2     user.video.lecture.action
# 3     user.video.lecture.action
# 4     user.video.lecture.action
# ..                          ...
# 233                    pageview
# 234   user.video.lecture.action
# 235   user.video.lecture.action
# 236   user.video.lecture.action
# 237                    pageview
#
#                                                  value  \
# 0                                                   {}
# 1                                                   {}
# 2     {\currentTime\:152.39935302734375,\playbackRa...
# 3     {\currentTime\:167.00390625,\playbackRate\:2,...
# 4     {\currentTime\:196.21298217773438,\playbackRa...
# ..                                                 ...
# 233                                                 {}
# 234   {\currentTime\:0,\playbackRate\:1,\paused\:tr...
# 235   {\currentTime\:283.8022155761719,\playbackRat...
# 236   {\currentTime\:0,\playbackRate\:1,\paused\:fa...
# 237                                                 {}
#
#                                       username               timestamp  \
# 0     728a8ca729e62014cf146709f8dfceddb3afc170 2013-05-10 20:25:15.281
# 1     728a8ca729e62014cf146709f8dfceddb3afc170 2013-05-10 20:25:15.334
# 2     1d9e48276af48ba4d2e4ceb753200143302457e9 2013-05-10 20:25:16.077
# 3     1d9e48276af48ba4d2e4ceb753200143302457e9 2013-05-10 20:25:16.923
# 4     1d9e48276af48ba4d2e4ceb753200143302457e9 2013-05-10 20:25:18.608
# ..                                         ...                     ...
# 233   246f9877ed2a111a19565237116faafbcf8b4224 2013-05-10 20:31:45.782
# 234   c16a6fe0421893b83ff0924ff356d0db1027609f 2013-05-10 20:31:48.279
# 235   9f195402d917fc3f616a035ce69e142332f8ceff 2013-05-10 20:31:53.339
# 236   c16a6fe0421893b83ff0924ff356d0db1027609f 2013-05-10 20:31:53.569
# 237   a246e228965378af68fb880ff0c7d27770e4e776 2013-05-10 20:31:53.671
#
#                                               page_url  client  \
# 0     https://class.coursera.org/psy-001/human_grad...   spark
# 1     https://class.coursera.org/psy-001/wiki/view?...   spark
# 2     https://class.coursera.org/psy-001/lecture/vi...   spark
# 3     https://class.coursera.org/psy-001/lecture/vi...   spark
# 4     https://class.coursera.org/psy-001/lecture/vi...   spark
# ..                                                 ...     ...
# 233   https://class.coursera.org/psy-001/wiki/view?...   spark
# 234   https://class.coursera.org/psy-001/lecture/vi...   spark
# 235   https://class.coursera.org/psy-001/lecture/vi...   spark
# 236   https://class.coursera.org/psy-001/lecture/vi...   spark
# 237   https://class.coursera.org/psy-001/quiz/start...   spark
#
#                        session                              language  \
# 0     1318904033-1368216996291                        es-ES,es;q=0.8
# 1     1318904033-1368216996291                        es-ES,es;q=0.8
# 2     8579605985-1368217057801               es,en-US;q=0.8,en;q=0.6
# 3     8579605985-1368217057801               es,en-US;q=0.8,en;q=0.6
# 4     8579605985-1368217057801               es,en-US;q=0.8,en;q=0.6
# ..                         ...                                   ...
# 233   4999032752-1368213768654                                 es-es
# 234   1825227370-1368217101956                        en-US,en;q=0.8
# 235   6045169376-1368215391831   ru-RU,ru;q=0.8,en-US;q=0.6,en;q=0.4
# 236   1825227370-1368217101956                        en-US,en;q=0.8
# 237   3719122221-1368210759589                                 es-es
#
#                                                   from           user_ip  \
# 0     https://class.coursera.org/psy-001/wiki/view?...       66.98.43.34
# 1     https://class.coursera.org/psy-001/human_grad...       66.98.43.34
# 2     https://class.coursera.org/psy-001/lecture/vi...     81.37.199.142
# 3     https://class.coursera.org/psy-001/lecture/vi...     81.37.199.142
# 4     https://class.coursera.org/psy-001/lecture/vi...     81.37.199.142
# ..                                                 ...               ...
# 233   https://class.coursera.org/psy-001/lecture/index       88.7.114.56
# 234      https://class.coursera.org/psy-001/lecture/71    98.253.201.233
# 235   https://class.coursera.org/psy-001/lecture/vi...      93.74.47.244
# 236   https://class.coursera.org/psy-001/lecture/vi...    98.253.201.233
# 237      https://class.coursera.org/psy-001/quiz/index   201.143.189.105
#
#                                             user_agent
# 0     Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537....
# 1     Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537....
# 2     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 3     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 4     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# ..                                                 ...
# 233   Mozilla/5.0 (iPad; CPU OS 6_1_3 like Mac OS X...
# 234   Mozilla/5.0 (Linux; Android 4.0.4; BNTV600 Bu...
# 235   Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537....
# 236   Mozilla/5.0 (Linux; Android 4.0.4; BNTV600 Bu...
# 237   Mozilla/5.0 (iPad; CPU OS 6_1 like Mac OS X) ...
#
# [238 rows x 11 columns]

# %% [markdown]
# # Most viewed videos

# %%
Coursera_df.groupby(["page_url"]).size().sort_values(ascending=False).head(6)
# Out:
# page_url
#  https://class.coursera.org/psy-001/lecture/view?lecture_id=17    82
#  https://class.coursera.org/psy-001/lecture/view?lecture_id=23    18
#  https://class.coursera.org/psy-001/forum/index                   15
#  https://class.coursera.org/psy-001/quiz/index                    12
#  https://class.coursera.org/psy-001/learning_tool/index?tool=1    12
#  https://class.coursera.org/psy-001/lecture/view?lecture_id=45    12
# dtype: int64

# %% [markdown]
# # Users most used language

# %%
Coursera_df.groupby(["language"]).size().sort_values(ascending=False)
# Out:
# language
#  es,en-US;q=0.8,en;q=0.6                82
#  en-US,en;q=0.5                         66
#  en-US,en;q=0.8                         27
#  en-us                                  18
#  ru-RU,ru;q=0.8,en-US;q=0.6,en;q=0.4    18
#  es-ES,es;q=0.8                         12
#  es-es                                   9
#  en-US                                   6
# dtype: int64

# %% [markdown]
# # List of most active users

# %%
Coursera_df.groupby(["username"]).size().sort_values(ascending=False).head(6)
# Out:
# username
#  1d9e48276af48ba4d2e4ceb753200143302457e9    82
#  9357db92c5f38c49dc13fbe4cc91b49f57203319    60
#  1b96e57806c28adcc362aba1d97ec2c8f942b51e    18
#  9f195402d917fc3f616a035ce69e142332f8ceff    18
#  c16a6fe0421893b83ff0924ff356d0db1027609f    15
#  728a8ca729e62014cf146709f8dfceddb3afc170    12
# dtype: int64

# %% [markdown]
# # Most Used Internet Browser

# %%
 Coursera_df["browser"]=Coursera_df["user_agent"].apply(lambda ua: user_agent_parser.Parse(ua))

# %%
 Coursera_df["browser"]=Coursera_df["browser"].apply(lambda x: x["user_agent"]["family"])

# %%
Coursera_df.groupby(["browser"]).size()
# Out:
# browser
# Chrome           139
# Firefox           66
# IE                 6
# Mobile Safari      9
# Safari            18
# dtype: int64
